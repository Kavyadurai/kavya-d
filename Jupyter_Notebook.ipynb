# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Tools For DataScience

# %% [markdown]
# Exercise 3 - Create a markdown cell for an introduction.

# %% [markdown]
# This simple Jupyterlite notebook for Peer-graded_Assignment_Submitting_My_Work atcourse of tools of data scientist via IBM coursera courses , to complete this assignment. I needed to include a combination of markdown and code cells.

# %% [markdown]
# Exercise 4 - Create a markdown cell to list data science languages.

# %% [markdown]
# In data sciece there are many languages are used from different organiztions ,The popular languages are:
#
# Python
# R
# SQL
# Scala
# Java
# C++
# Julia
# JavaScript
# PHP
# Go
# Ruby
# Visual Basic
# all have their own unique use cases as well ,You should select a language to learn depending on your needs, the problems you are trying to solve, and whom you are solving them for.

# %% [markdown]
# Exercise 5 - Create a markdown cell to list data science libraries.

# %% [markdown]
# There are many libraries are used in unordered list ,you can use :
# 1. Python's scientific computing libraries :
# Pandas
# NumPy
# SciPy
# Matplotlib
# seaborn
# .
# 2. Python's artificial intelligence libraries:
# TensorFlow
# PyTorch
# Keras
# Scikit-learn
#
# 3. Python's Natural Language Processing (NLP) using the Natural Language Toolkit (NLTK).
# 4.spark (apache spark)
# 5.vegas (scala)
# 6.ggplot2 (R)

# %% [markdown]
# Exercise 6 - Create a markdown cell with a table of Data Science tools.

# %% [markdown]
# Data science tools built with |Programming Laguage|Tools| | --- | --- | | Java | Weka, Java-ML, Apache MLlib, and Deeplearning4 | |Scala |Apache Spark, that includes Shark, MLlib, GraphX, and Spark Streaming| | C++ |TensorFlow, MongoDB and Caffe|
# |JavaScript |TensorFlow.js and R-js| Julia | JuliaDB|

# %% [markdown]
# Exercise 7 - Create a markdown cell introducing arithmetic expression examples

# %%
#arithmetic operation
a=2+3
a
# Out:
# 5

# %%
import math
v=math.pow(25,3)
v
# Out:
# 15625.0

# %% [markdown]
# Exercise 8 - Create a code cell to multiply and add numbers.

# %%
(8*5)+12
# Out:
# 52

# %% [markdown]
# Exercise 9 - Create a code cell to convert minutes to hours.

# %%
min=int(input("enter time in minutes"))
h=min//60
h
# Out:
# 1

# %% [markdown]
# Exercise 10 -Insert a markdown cell to list Objectives.

# %% [markdown]
# Objectives:
# List popular languages that Data Scientists use.
# List commonly used libraries used by Data Scientists.
# different Data Science tools.

# %% [markdown]
# Exercise 11 - Create a markdown cell to indicate the Author’s name.

# %%
author,
Kavya
